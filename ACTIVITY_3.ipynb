# %% [markdown]
# <a href="https://colab.research.google.com/github/Mark19-prog/FINANCE-PROJECT/blob/main/ACTIVITY_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark.sql import SparkSession

# Start the Spark Session
spark = SparkSession.builder.appName("HospitalAnalysis").getOrCreate()

# Load the dataset
# header=True uses the first row as column names
# inferSchema=True detects numbers vs strings automatically
rdd = spark.read.csv("hospital_readmission_dataset.csv", header=True, inferSchema=True)

# %%
# 2. Partition by Range based on Age
# This sorts the data and splits it into 5 logical age-based buckets.
rddRangeAge = rdd.repartitionByRange(5, "age")

# %%
# Transformation: Filtering for seniors
# Because the data is range-partitioned, Spark knows exactly which partitions to scan.
SeniorsOnly = rddRangeAge.filter("age >= 65")

# %%
# Transformation: Sort within partitions
FinalSeniors = SeniorsOnly.sort("age")

# Result
FinalSeniors.show()
# Out:
# +----------+--------------+------+---+------+-------+-----------------+-------------------+--------------+--------------+-----------------+-------------------------+-----------------+--------------+---------------------+----------------------+-----+
# |patient_id|admission_date|season|age|gender| region|primary_diagnosis|comorbidities_count|length_of_stay|treatment_type|medications_count|followup_visits_last_year|prev_readmissions|insurance_type|discharge_disposition|readmission_risk_score|label|
# +----------+--------------+------+---+------+-------+-----------------+-------------------+--------------+--------------+-----------------+-------------------------+-----------------+--------------+---------------------+----------------------+-----+
# |    P00788|    2021-07-19|Summer| 65|  Male|   East|   Kidney Disease|                  5|             9|       Medical|                8|                        4|                1|      Medicaid|          Home Health|                  0.97|    1|
# |    P01575|    2022-10-04|  Fall| 65|  Male|  South|         Diabetes|                  4|             6|  Conservative|                6|                        2|                1|       Private|          Home Health|                  0.65|    0|
# |    P00791|    2023-07-26|Summer| 65|Female|  South|             COPD|                  5|             9|      Surgical|               10|                        4|                1|       Private|          Home Health|                  0.97|    1|
# |    P00690|    2021-07-17|Summer| 65|Female|   East|         Fracture|                  4|             9|  Conservative|                6|                        3|                1|     Uninsured|          Home Health|                  0.73|    1|
# |    P00935|    2021-08-31|Summer| 65|  Male|  South|           Stroke|                  5|            12|       Medical|                8|                        4|                1|     Uninsured|          Home Health|                  0.97|    1|
# |    P00259|    2022-11-30|  Fall| 65|Female|   West|         Diabetes|                  5|             7|       Medical|                8|                        2|                1|       Private|          Home Health|                  0.82|    1|
# |    P00958|    2021-12-07|Winter| 65|Female|   East|             COPD|                  5|             8|      Surgical|                8|                        4|                2|      Medicaid|          Home Health|                  0.97|    1|
# |    P00605|    2022-07-01|Summer| 65|  Male|  North|   Kidney Disease|                  4|             8|      Surgical|                8|                        4|                1|      Medicaid|          Home Health|                  0.97|    1|
# |    P00960|    2022-05-24|Spring| 65|Female|   West|         Diabetes|                  4|             8|       Medical|                6|                        3|                2|       Private|          Home Health|                  0.81|    1|
# |    P01196|    2021-06-07|Summer| 65|Female|Central|           Stroke|                  4|             9|       Medical|                6|                        2|                2|       Private|          Home Health|                  0.97|    1|
# |    P01546|    2021-02-17|Winter| 65|  Male|   East|             COPD|                  4|             9|       Medical|                8|                        2|                1|       Private|          Home Health|                  0.95|    1|
# |    P01224|    2021-06-24|Summer| 65|  Male|   West|     Appendicitis|                  4|             7|      Surgical|                6|                        4|                1|       Private|          Home Health|                  0.64|    1|
# |    P00166|    2021-02-08|Winter| 65|Female|   West|             COPD|                  4|            10|      Surgical|                7|                        3|                1|      Medicaid|          Home Health|                  0.93|    1|
# |    P01258|    2023-10-30|  Fall| 65|Female|   West|     Appendicitis|                  4|             6|  Conservative|                7|                        2|                1|     Uninsured|          Home Health|                  0.73|    0|
# |    P00982|    2021-06-24|Summer| 65|  Male|  North|   Kidney Disease|                  4|             8|       Medical|                6|                        2|                1|       Private|          Home Health|                  0.85|    1|
# |    P01343|    2022-01-01|Winter| 65|Female|   East|           Sepsis|                  4|            11|       Medical|                7|                        4|                1|      Medicaid|          Home Health|                  0.97|    1|
# |    P01026|    2023-12-10|Winter| 65|Female|   West|         Diabetes|                  4|             9|      Surgical|                7|                        3|                1|      Medicaid|          Home Health|                  0.67|    1|
# |    P01134|    2021-01-15|Winter| 65|  Male|  South|        Pneumonia|                  4|             8|Interventional|                6|                        3|                1|       Private|          Home Health|                  0.63|    0|
# |    P00276|    2021-04-26|Spring| 65|Female|Central|     Hypertension|                  4|             5|      Surgical|                6|                        4|                1|     Uninsured|          Home Health|                  0.72|    1|
# |    P00339|    2022-06-28|Summer| 65|Female|   East|     Hypertension|                  4|             6|      Surgical|                6|                        3|                1|       Private|          Home Health|                  0.59|    1|
# +----------+--------------+------+---+------+-------+-----------------+-------------------+--------------+--------------+-----------------+-------------------------+-----------------+--------------+---------------------+----------------------+-----+
# only showing top 20 rows

# %%
ReducedPartition = FinalSeniors.coalesce(2)

# %%
UniqueSeniors = ReducedPartition.distinct()

# %%
TotUniSen = UniqueSeniors.count()

print("Total unique senior records:", TotUniSen)
# Out:
# Total unique senior records: 2712

# %%
#ACTIVITY #4 BIG DATA ANALYSIS
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg, min, max
import shutil
from google.colab import files

spark = (SparkSession.builder.appName("Activity #4 ni Nash Mapula").getOrCreate())

schema = "CustomerID INT, Gender STRING, Age DOUBLE, Annual_Income DOUBLE, Spending_Score Double"

DF = spark.read.csv("store_customers.csv", header=True, schema=schema)


DF_distinct = DF.distinct()


DFCleaned = DF_distinct.dropna()

print("Cleaned Data Sample")
DFCleaned.show(5)
# Out:
# Cleaned Data Sample
# +----------+------+----+-------------+--------------+
# |CustomerID|Gender| Age|Annual_Income|Spending_Score|
# +----------+------+----+-------------+--------------+
# |      1341|     M|37.0|         33.5|          56.0|
# |      1378|     M|53.0|         86.1|          28.0|
# |      1541|     M|26.0|         22.1|          73.0|
# |      1576|     M|37.0|         44.9|          37.0|
# |      1171|     M|28.0|         26.4|          46.0|
# +----------+------+----+-------------+--------------+
# only showing top 5 rows
